# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.cross_validation import cross_val_score
from sklearn import metrics
from sklearn import preprocessing

import warnings
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
movies_dataframe = pd.read_csv('movie_metadata_usa.csv')
movies_dataframe.head()
# Out:
#               color  num_critic_for_reviews  duration  \
# 0             Color                      35        91
# 1             Color                     228        86
# 2             Color                     149        91
# 3   Black and White                     360        81
# 4             Color                     124        90
#
#    director_facebook_likes      gross  num_voted_users  \
# 0                       32  130512915            60884
# 1                       17   17683670            47227
# 2                       17   41867960            65512
# 3                       19  140530114           186786
# 4                       63  217350219           260939
#
#    cast_total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 0                       3244                     2                    85
# 1                       1520                     0                   323
# 2                       3023                     0                   478
# 3                        399                     0                  3400
# 4                      52970                     0                   244
#
#   language country content_rating    budget  title_year  imdb_score  \
# 0  English     USA             PG  45000000        1994         4.8
# 1  English     USA          PG-13   5000000        2011         5.2
# 2  English     USA              R  20000000        2001         5.5
# 3  English     USA              R     60000        1999         6.4
# 4  English     USA              G  28000000        1992         8.0
#
#    aspect_ratio  movie_facebook_likes
# 0          1.33                     0
# 1          1.33                     0
# 2          1.33                     0
# 3          1.33                     0
# 4          1.33                     0

# %%
# Gross vs. IMDB Score

x_axis = movies_dataframe['imdb_score']
y_axis = movies_dataframe['gross']

# %matplotlib inline
plt.ylabel('Gross')
plt.xlabel('IMDB Score')

plt.ylim([0, 1000000000])           #Gross limit of $1B
plt.xlim([0, 10])                   #IMDB score range from 0 - 10
plt.scatter(x_axis, y_axis, alpha=0.5)
plt.show()

# %%
# Gross vs. Budget

x_axis = movies_dataframe['budget']

plt.ylabel('Gross')
plt.xlabel('Budget')

plt.ylim([0, 1000000000])           #Gross limit of $1B
plt.xlim([0, 350000000])            #Budget limit of $350M
plt.scatter(x_axis, y_axis, alpha=0.5)
plt.show()

# %%
# Gross vs. Duration

x_axis = movies_dataframe['duration']

plt.ylabel('Gross')
plt.xlabel('Duration (minutes)')

plt.ylim([0, 1000000000])           #Gross limit of $1B
plt.xlim([0, 350])                  #Durtaion limit of 350 minutes (looong movies)
plt.scatter(x_axis, y_axis, alpha=0.5)
plt.show()

# %%
# Gross vs. Title Year

x_axis = movies_dataframe['title_year']

plt.ylabel('Gross')
plt.xlabel('Title Year')

plt.ylim([0, 1000000000])           #Gross limit of $1B
plt.xlim([1920, 2020])              #Title Year range of 1920 - 2020
plt.scatter(x_axis, y_axis, alpha=0.5)
plt.show()

# %%
# Gross vs. Face Number in Poster

x_axis = movies_dataframe['facenumber_in_poster']

plt.ylabel('Gross')
plt.xlabel('Face Number in Poster')

plt.ylim([0, 1000000000])           #Gross limit of $1B
plt.xlim([0, 50])                   #Faces in poster limit of 50
plt.scatter(x_axis, y_axis, alpha=0.5)
plt.show()

# %%
# Gross vs. Cast Total Facebook Likes

x_axis = movies_dataframe['cast_total_facebook_likes']

plt.ylabel('Gross')
plt.xlabel('Cast Total Facebook Likes')

plt.ylim([0, 1000000000])           #Gross limit of $1B
plt.xlim([0, 700000])               #Cast Facebook Like limit of 700,000
plt.scatter(x_axis, y_axis, alpha=0.5)
plt.show()

# %%
# Gross vs. Director Facebook Likes

x_axis = movies_dataframe['director_facebook_likes']

plt.ylabel('Gross')
plt.xlabel('Director Facebook Likes')

plt.ylim([0, 1000000000])           #Gross limit of $1B
plt.xlim([0, 25000])                #Director Facebook Likes limit of 25000 (no love for the directors)
plt.scatter(x_axis, y_axis, alpha=0.5)
plt.show()

# %%
# Function to convert color values to binary values
def categorical_to_numeric(x):
    if x == 'Color':
        return 1;
    else:
        return 0;
    
# Creates a new feature named ColorLabel using converted values
movies_dataframe['ColorLabel'] = movies_dataframe['color'].apply(categorical_to_numeric)
movies_dataframe.head()
# Out:
#               color  num_critic_for_reviews  duration  \
# 0             Color                      35        91
# 1             Color                     228        86
# 2             Color                     149        91
# 3   Black and White                     360        81
# 4             Color                     124        90
#
#    director_facebook_likes      gross  num_voted_users  \
# 0                       32  130512915            60884
# 1                       17   17683670            47227
# 2                       17   41867960            65512
# 3                       19  140530114           186786
# 4                       63  217350219           260939
#
#    cast_total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 0                       3244                     2                    85
# 1                       1520                     0                   323
# 2                       3023                     0                   478
# 3                        399                     0                  3400
# 4                      52970                     0                   244
#
#   language country content_rating    budget  title_year  imdb_score  \
# 0  English     USA             PG  45000000        1994         4.8
# 1  English     USA          PG-13   5000000        2011         5.2
# 2  English     USA              R  20000000        2001         5.5
# 3  English     USA              R     60000        1999         6.4
# 4  English     USA              G  28000000        1992         8.0
#
#    aspect_ratio  movie_facebook_likes  ColorLabel
# 0          1.33                     0           1
# 1          1.33                     0           1
# 2          1.33                     0           1
# 3          1.33                     0           0
# 4          1.33                     0           1

# %%
# Gross vs. Color

x_axis = movies_dataframe['ColorLabel']

plt.ylabel('Gross')
plt.xlabel('Color')

plt.ylim([0, 1000000000])           # Gross limit of $1B
plt.xlim([-0.2,1.2])                # ColorLabel range -0.2 - 1.2 for clarity with binary values
plt.scatter(x_axis, y_axis, alpha=0.5)
plt.show()

# %%
X_scaled = movies_df[[ 'num_user_for_reviews','cast_total_facebook_likes','director_facebook_likes','num_critic_for_reviews', 'budget', 'imdb_score', 'title_year', 'num_voted_users','duration', 'facenumber_in_poster']]

X_scaled = X_scaled[[ 'budget', 'imdb_score', 'title_year', 'num_voted_users','duration', 'facenumber_in_poster']]
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=2)

# %%
movies_dataframe_2 = pd.read_csv('movie_metadata_usa500.csv')
movies_dataframe_2.head()
# Out:
#               color  num_critic_for_reviews  duration  \
# 0             Color                       9        96
# 1             Color                      11       106
# 2             Color                      29        87
# 3   Black and White                      94       106
# 4             Color                      10        95
#
#    director_facebook_likes  gross  num_voted_users  cast_total_facebook_likes  \
# 0                      436    703              480                        920
# 1                       15   1111              771                          2
# 2                       38   1332             2038                       2251
# 3                        5   2436              344                       1611
# 4                        0   2468              241                       2048
#
#    facenumber_in_poster  num_user_for_reviews language country content_rating  \
# 0                     3                    21  English     USA              R
# 1                     0                    10  English     USA          PG-13
# 2                     6                    20  English     USA      Not Rated
# 3                     2                    19  English     USA      Not Rated
# 4                     3                     5  English     USA              R
#
#     budget  title_year  imdb_score  aspect_ratio  movie_facebook_likes
# 0  1500000        2001         5.4          1.85                    47
# 1   200000        2006         7.7          1.66                   246
# 2   500000        2012         4.6          2.35                   898
# 3  2000000        2012         5.7          2.35                   655
# 4   300000        2014         4.8          1.85                   261

# %%
feature_scaled = movies_dataframe[['num_user_for_reviews','cast_total_facebook_likes','director_facebook_likes','num_critic_for_reviews','budget','imdb_score','title_year','num_voted_users','duration','facenumber_in_poster']]
feature_scaled = feature_scaled.apply(lambda x: ((x - x.min()) / (x.max() - x.min())))

# Added the color column after averaging to avoid conflictions
feature_scaled['ColorLabel'] = movies_dataframe['color']

feature_scaled.head()
# Out:
#    num_user_for_reviews  cast_total_facebook_likes  director_facebook_likes  \
# 0              0.018003                   0.004940                 0.001391
# 1              0.069010                   0.002314                 0.000739
# 2              0.102229                   0.004603                 0.000739
# 3              0.728461                   0.000608                 0.000826
# 4              0.052079                   0.080657                 0.002739
#
#    num_critic_for_reviews    budget  imdb_score  title_year  num_voted_users  \
# 0                0.041872  0.149999    0.415584    0.747126         0.036019
# 1                0.279557  0.016666    0.467532    0.942529         0.027936
# 2                0.182266  0.066666    0.506494    0.827586         0.038757
# 3                0.442118  0.000199    0.623377    0.804598         0.110528
# 4                0.151478  0.093333    0.831169    0.724138         0.154412
#
#    duration  facenumber_in_poster        ColorLabel
# 0  0.184300              0.046512             Color
# 1  0.167235              0.000000             Color
# 2  0.184300              0.000000             Color
# 3  0.150171              0.000000   Black and White
# 4  0.180887              0.000000             Color
